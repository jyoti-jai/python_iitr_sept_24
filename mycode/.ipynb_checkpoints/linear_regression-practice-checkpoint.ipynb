# %% [markdown]
# Problem Statement - For three data points (1,2), (2,3), (3,5) solve the linear regression for the values of m, c where the total error is minimum
#
# The prediction line is yp=mx+c4 For any data point the error is y-actual(ya) - y-predicted(yp). i.e. E(Error)=ya - yp
#
# For first data point x=1 and ya=2, yp=mx+c yp=m+c E1(Error)=ya - yp E1(Error) = 2 - (m+c)
#
# For second data point x=2 and ya=3, yp=mx+c yp=m*2+c E2(Error) = 3 - (2m+c)
#
# For first data point x=3 and ya=5, yp=mx+c yp=m*3+c E3(Error) = 5 - (3m+c)
#
# For calculating total error we square each error, to make negatives into positives.
#
# So TotalError = E12+E22+E3**2
#
# TE=(2-(m+c))**2 + (3 - (2m+c))**2 + (5 - (3m+c))**2
#
# Write the program for each permutaion of m,c in the range of 0-100 with inrease of .1, so that to find the value of m,c that results in the minimum total error.

# %%
def finderror(m,c):
    error=(2-(m+c))**2 + (3 - (2*m+c))**2 + (5 - (3*m+c))**2
    return error

def findbestprediction0(x_array, y_array):
    m=0.0
    result=None
    while m <=100:
        c=0.0
        while c<=100:
            error=finderror(m,c)
            if (result==None or (len(result) > 0 and error < result[0])):
                print(f"{error},{m},{c}")
                result=[error,m,c]
            c+=.1
        m+=.1
    return result

# %%
def findpredictedy(m,c,x_orig):
    # print(f"m:{m},c{c},x_orig{x_orig}")
    y_pred=[m * x + c for x in x_orig]
    return y_pred
    
def findtotalerror(y_orig, y_pred):
    errors=[(y_orig[i] - y_pred[i]) **2 for i in range(len(y_orig))]
    return sum(errors)

def finderror(m,c,x_orig,y_orig):
    y_pred=findpredicted
    errors=[(y_orig[i] - y_pred[i]) **2 for i in range(len(y_orig))]
    return sum(errors)

def findbestprediction(x_orig, y_orig):
    leftm=0.0
    rightm=10.0
    c=0.0
    result=None
    num_iterations = 100
    change = .000001
    for i in range(num_iterations):
        if (abs(rightm - leftm) < change):
            break
        y_pred=findpredictedy(leftm,c,x_orig)
        lefttotal=findtotalerror(y_orig,y_pred)
        
        y_pred=findpredictedy(rightm,c,x_orig)
        righttotal=findtotalerror(y_orig,y_pred)
        
        m = leftm if lefttotal < righttotal  else rightm
        l_m= m - change
        r_m= m + change
        y_pred=findpredictedy(l_m,c,x_orig)
        l_error=findtotalerror(y_orig,y_pred)
        y_pred=findpredictedy(r_m,c,x_orig)
        r_error=findtotalerror(y_orig,y_pred)
        if (m == leftm):
            if (l_error < r_error):
                leftm, rightm = 2 * leftm - rightm, leftm
                result= [l_error,m,c]
            else:
                rightm = (leftm+rightm)/2
                result= [r_error,m,c]
        else:
            if (l_error < r_error):
                result= [l_error,m,c]
                leftm = (leftm+rightm)/2
            else:
                leftm, rightm = rightm, 2*rightm - leftm
                result= [r_error,m,c]
        print(f"{i}.Result:{result}")
    return result

# %%
def predicty(m,c,x_orig):
    # print(f"m:{m},c{c},x_orig{x_orig}")
    y_pred=[m * x + c for x in x_orig]
    return y_pred
    
def finderrorsum(y_orig, y_pred):
    errors=[(y_orig[i] - y_pred[i]) **2 for i in range(len(y_orig))]
    return sum(errors)

def findtotalerror(m,c,x_orig,y_orig):
    y_pred=predicty(m,c,x_orig)
    return (finderrorsum(y_orig,y_pred))

def findbesterror(m_array,c_array,x_orig,y_orig):
    besterror = float('inf')
    result=None
    for m in m_array
        for c in c_array
            totalerror = findtotalerror(m,c,x_orig,y_orig)
            if (totalerror < besterror)
                besterror = totalerror
                result = (totalerror,m,c)
    return result
        

def findbestprediction(x_orig, y_orig):
    leftm=0.0
    rightm=10.0
    leftc=0.0
    rightc=10.0
    c=0.0
    result=None
    num_iterations = 100
    change = .000001
    for i in range(num_iterations):
        if (abs(rightm - leftm) < change):
            break
        leftm_error=findtotalerror(leftm,c,x_orig,y_orig)
        rightm_error=findtotalerror(rightm,c,x_orig,y_orig)
        
        m = leftm if leftm_error < rightm_error  else rightm
        l_m= m - change
        r_m= m + change
        
        lm_error=findtotalerror(l_m,c,x_orig,y_orig)
        rm_error=findtotalerror(r_m,c,x_orig,y_orig)
        if (m == leftm):
            if (lm_error < rm_error):
                leftm, rightm = 2 * leftm - rightm, leftm
                result= [lm_error,m,c]
            else:
                rightm = (leftm+rightm)/2
                result= [rm_error,m,c]
        else:
            if (lm_error < rm_error):
                result= [lm_error,m,c]
                leftm = (leftm+rightm)/2
            else:
                leftm, rightm = rightm, 2*rightm - leftm
                result= [rm_error,m,c]
        print(f"{i}.Result:{result}")
    return result

# %%
def predicty(m,c,x_orig):
    # print(f"m:{m},c{c},x_orig{x_orig}")
    y_pred=[m * x + c for x in x_orig]
    return y_pred
    
def finderrorsum(y_orig, y_pred):
    errors=[(y_orig[i] - y_pred[i]) **2 for i in range(len(y_orig))]
    return sum(errors)

def findtotalerror(m,c,x_orig,y_orig):
    y_pred=predicty(m,c,x_orig)
    return (finderrorsum(y_orig,y_pred))

def findbesterror(m_array,c_array,x_orig,y_orig):
    # print("Calculating best error for:",m_array,c_array)
    besterror = float('inf')
    result=None
    for m in m_array:
        for c in c_array:
            totalerror = findtotalerror(m,c,x_orig,y_orig)
            if (totalerror < besterror):
                besterror = totalerror
                result = (totalerror,m,c)
    # print("Returning best error as:",result)
    return result

def findnewvalues(resultval,leftval,rightval, direction):
    if (resultval == leftval):
        if (direction==-1):
            leftval, rightval = 2 * leftval - rightval, leftval
        else:
            rightval = (leftval + rightval)/2
    else:
        if (direction==-1):
            leftval = (leftval + rightval)/2
        else:
            leftval, rightval = rightval, 2*rightval - leftval
    return (leftval, rightval)
    
    
def findbestprediction(x_orig, y_orig):
    leftm=0.0
    rightm=10.0
    leftc=0.0
    rightc=10.0
    bestresult=None
    num_iterations = 100000
    change = .000001
    
    for i in range(num_iterations):
        # if (abs(rightm - leftm) < change):
        #     break
         
        bestresult = findbesterror([leftm,rightm],[leftc,rightc],x_orig,y_orig)
        error,m,c = bestresult
       
        l_m= m - change
        r_m= m + change
        result = findbesterror([l_m,r_m],[c],x_orig,y_orig)
        m_direction = -1 if result[1] == l_m  else 1

        l_c= c - change
        r_c= c + change
        result = findbesterror([m],[l_c,r_c],x_orig,y_orig)
        c_direction = -1 if result[2] == l_c  else 1

        leftm, rightm = findnewvalues(m,leftm,rightm, m_direction)
        leftc, rightc = findnewvalues(c,leftc,rightc, c_direction)
        # print(f"leftm:{leftm}, rightm:{rightm}, leftc:{leftc}, rightc:{rightc}")
                
        # print(f"{i+1}.Result after this iteration:{bestresult}")
    return bestresult

# %%
t = (5,6,7)
a=[1,2,3]
print(t,a)
t=(8,9,7)
print(t,a)
t
# Out:
# (5, 6, 7) [1, 2, 3]
# (8, 9, 7) [1, 2, 3]

# %%
# x= [1, 2, 3]
# y= [2, 3, 5]
x= [10, 11, 12,9]
y= [13, 14, 19,8]
r = findbestprediction(x,y)
print("Final Result", r)
# 200 Final Result (48.518797755241394, 0.391845703125, 9.521484375)
# 500 Final Result (42.077262848615646, 0.6170654296875, 7.216796875)
# 1000 Final Result (37.238696068525314, 0.7952880859375, 5.31982421875)
# 10000 Final Result (24.110346863017185, 1.3556480407714844, -0.67626953125)
# 100000 Final Result (15.870769191922136, 1.8164992332458496, -5.390625)
# Out:
# Final Result (15.870769191922136, 1.8164992332458496, -5.390625)

# %%
array=[[2,1],[3,0],[1,1],[1,0]]
r= array.sort()
print (array)
# Out:
# [[1, 0], [1, 1], [2, 1], [3, 0]]

# %%
#Incomplete. Not possible to do binary search this way
def findbestprediction2():
    result=None
    leftm=1
    rightm=2
    target = .25
    m =0.0
    c=0.0

    while leftm < rightm:
        midm=(leftm+rightm)/2
        leftc=0
        rightc=1
        marray=[leftm,midm,rightm]
        for i in range(len(marray):
            m = marray[i]
            outer_results=[]
            while leftc < rightc:
                midc=(leftc+rightc)/2
                carray=[leftc,midc,rightc]
                inner_results=[]
                found=false
                min_result=None
                for j in range(len(carray)):
                    c = carray[j]
                    error=finderror(m,c)
                    inner_results.append[error,c,j]
                inner_results.sort()
               
                best_result=inner_results[0]
                next_result=inner_results[1]
                if (best_result[0] <= target):
                    return [best_result[0], m, best_result[1]]
                if ((min_result)==None
                if (best_result[2]==0):
                    rightc=midc-.1
                elif (best_result[2]==2):
                    left=midc+.1
                elif (next_result[2]==0):
                    rightc=midc
                    leftc=leftc +.1
                else:
                    leftc=midc
                    rightc=rightc -.1
                # print(f"{error},{midm},{rightc}")
                
                
        m+=.1
    return result

# %%
r = findbestprediction()

# %%
arr = [1,2,3]
for i in arr:
    print(i)
# Out:
# 1
# 2
# 3

# %%
# Dataset
# x = [1, 2, 3, 4]
# y = [2, 4, 6, 8]

x= [1, 2, 3]
y= [2, 3, 5]

# Parameters
m = 0
b = 0
learning_rate = 0.01
num_iterations = 1000

# Function to calculate predicted values
def predict(x, m, b):
    return [m * xi + b for xi in x]

# Gradient Descent
for _ in range(num_iterations):
    y_pred = predict(x, m, b)
    
    # Calculate gradients
    dm = -(2 / len(x)) * sum(x[i] * (y[i] - y_pred[i]) for i in range(len(x)))
    db = -(2 / len(x)) * sum((y[i] - y_pred[i]) for i in range(len(x)))

    print(f"dm:{dm}, db:{db}")
    
    # Update parameters
    m = m - learning_rate * dm
    b = b - learning_rate * db

print(f"Optimized m: {m}")
print(f"Optimized b: {b}")
# Out:
# dm:-15.333333333333332, db:-6.666666666666666
# dm:-13.635555555555557, db:-5.92
# dm:-12.126103703703702, db:-5.256177777777777
# dm:-10.784086913580246, db:-4.666010074074074
# dm:-9.590931732016461, db:-4.141326396049383
# dm:-8.530125047852948, db:-3.674862598847737
# dm:-7.586985539432764, db:-3.2601603449566636
# dm:-6.748460475287439, db:-2.8914777164802197
# dm:-6.002945055601403, db:-2.563709743139118
# dm:-5.340121794019707, db:-2.272317746052279
# dm:-4.750817716735776, db:-2.013266519370445
# dm:-4.226877402398953, db:-1.782968480313606
# dm:-3.7610501056291743, db:-1.5782340146113758
# dm:-3.346889401852664, db:-1.3962273300939816
# dm:-2.978663964475989, db:-1.2344272074179954
# dm:-2.651278239494844, db:-1.090592104690596
# dm:-2.3602019196210344, db:-0.9627291330169904
# dm:-2.101407241802392, db:-0.8490664735718091
# dm:-1.8713132402912964, db:-0.7480288544282774
# dm:-1.6667361836869756, db:-0.6582157477280592
# dm:-1.4848455099670697, db:-0.5783819854260193
# dm:-1.3231246496197684, db:-0.5074205253188159
# dm:-1.179336194642506, db:-0.4443471288276495
# dm:-1.0514909313227658, db:-0.3882867384653963
# dm:-0.9378203081940246, db:-0.33846136644317737
# dm:-0.8367519581048557, db:-0.2941793267865531
# dm:-0.7468879356102722, db:-0.25482566192662726
# dm:-0.6669853684762496, db:-0.2198536312636842
# dm:-0.5959392555012523, db:-0.18877714389936054
# dm:-0.5327671725651606, db:-0.16116403080132313
# dm:-0.47659567522702506, db:-0.13663006328268984
# dm:-0.42664820967453015, db:-0.11483363500795565
# dm:-0.3822343647045899, db:-0.09547103392081564
# dm:-0.3427403159753264, db:-0.07827223865421487
# dm:-0.3076203302714614, db:-0.0629971812421178
# dm:-0.2763892121964416, db:-0.049432424406417486
# dm:-0.24861558874851752, db:-0.03738820743043162
# dm:-0.22391593883477215, db:-0.02669581973188251
# dm:-0.20194928508758547, db:-0.017205265783854173
# dm:-0.18241247451472287, db:-0.008783189064673458
# dm:-0.16503598266409664, db:-0.0013110263027916365
# dm:-0.14958018323000402, db:0.005316633529827511
# dm:-0.135832031469727, db:0.011193508188432233
# dm:-0.12360211552675733, db:0.016402919283452277
# dm:-0.11272203484893091, db:0.021018945518853784
# dm:-0.10304206941711976, db:0.025107448002433287
# dm:-0.09442910752495326, db:0.02872698181906911
# dm:-0.08676480342872168, db:0.03192960648368537
# dm:-0.07994393936805366, db:0.03476160649116118
# dm:-0.07387296928668144, db:0.03726413193606011
# dm:-0.06846872409736626, db:0.03947376806880657
# dm:-0.0636572605710309, db:0.041423041671325045
# dm:-0.05937283791792236, db:0.04314087126073929
# dm:-0.05555700789601155, db:0.0446529673522417
# dm:-0.05215780585314193, db:0.045982188321036656
# dm:-0.04912903150635328, db:0.04714885678874288
# dm:-0.04642960950397749, db:0.04817104091322181
# dm:-0.044023020920136435, db:0.049064804475116144
# dm:-0.04187679781325896, db:0.049844429222420196
# dm:-0.039962073852917904, db:0.05052261255050242
# dm:-0.03825318479533305, db:0.05111064325360888
# dm:-0.036727313277912746, db:0.05161855778035014
# dm:-0.0353641730165218, db:0.0520552791558595
# dm:-0.03414572803454474, db:0.05242874049340414
# dm:-0.033055943037725, db:0.05274599480491737
# dm:-0.032080561479732886, db:0.053013312630328414
# dm:-0.03120690824683662, db:0.053236268836911606
# dm:-0.030423714230607413, db:0.05341981979004713
# dm:-0.029720960360687165, db:0.053568371963470085
# dm:-0.029089738938893994, db:0.05368584293862858
# dm:-0.028522130355476644, db:0.05377571563741146
# dm:-0.028011093481129436, db:0.05384108653888179
# dm:-0.027550368217779564, db:0.053884708547349426
# dm:-0.02713438885934686, db:0.05390902910511371
# dm:-0.026758207063345047, db:0.05391622407738561
# dm:-0.026417423367194104, db:0.05390822787837202
# dm:-0.026108126301392993, db:0.05388676025549162
# dm:-0.025826838256814234, db:0.05385335010243815
# dm:-0.02557046735694405, db:0.05380935663066122
# dm:-0.025336264668855968, db:0.05375598819232567
# dm:-0.025121786160789895, db:0.05369431901523303
# dm:-0.024924858879726248, db:0.05362530408135975
# dm:-0.02474355088087169, db:0.053549792354921966
# dm:-0.0245761444928565, db:0.05346853854305748
# dm:-0.024421112548578112, db:0.05338221355191071
# dm:-0.024277097252786817, db:0.053291413782815766
# dm:-0.024142891393840404, db:0.05319666939727059
# dm:-0.0240174216396416, db:0.05309845166507794
# dm:-0.02389973368654156, db:0.052997179497363156
# dm:-0.023788979055693993, db:0.05289322525487705
# dm:-0.02368440335402481, db:0.05278691991200694
# dm:-0.023585335837462473, db:0.05267855764792806
# dm:-0.023491180131883855, db:0.05256839992846777
# dm:-0.023401405983379142, db:0.05245667913517386
# dm:-0.023315541923669542, db:0.05234360179180604
# dm:-0.023233168749134798, db:0.05222935143291603
# dm:-0.023153913723198784, db:0.052114091154222976
# dm:-0.023077445421869403, db:0.05199796588006651
# dm:-0.023003469151028945, db:0.05188110437934057
# dm:-0.02293172287210628, db:0.05176362105779504
# dm:-0.02286197357968896, db:0.05164561755152312
# dm:-0.022794014080979547, db:0.05152718414367996
# dm:-0.022727660132500233, db:0.05140840102404616
# dm:-0.02266274789443064, db:0.05128933940886456
# dm:-0.022599131667306278, db:0.051170062536463945
# dm:-0.02253668187981613, db:0.051050626552427016
# dm:-0.02247528329979816, db:0.050931081296570646
# dm:-0.0224148334436783, db:0.05081147100263165
# dm:-0.02235524116237523, db:0.050691834920325654
# dm:-0.02229642538403276, db:0.050572207868414466
# dm:-0.02223831399625927, db:0.050452620726407396
# dm:-0.022180842852331868, db:0.05033310087172952
# dm:-0.022123954887648917, db:0.050213672568388525
# dm:-0.022067599334203436, db:0.05009435731252705
# dm:-0.0220117310221782, db:0.04997517413964481
# dm:-0.021956309759028216, db:0.04985613989773885
# dm:-0.02190129977742661, db:0.04973726949014582
# dm:-0.02184666924447557, db:0.04961857609143886
# dm:-0.02179238982531606, db:0.049500071339388864
# dm:-0.02173843629519497, db:0.049381765505613906
# dm:-0.021684786194532624, db:0.04926366764731016
# dm:-0.02163141952226984, db:0.049145785742144746
# dm:-0.0215783184632099, db:0.049028126808192976
# dm:-0.0215254671456373, db:0.04891069701055765
# dm:-0.021472851425799057, db:0.048793501756172475
# dm:-0.021420458696305822, db:0.048676545778080595
# dm:-0.02136827771577421, db:0.048559833210371085
# dm:-0.021316298457384992, db:0.0484433676547941
# dm:-0.021264511974219115, db:0.048327152239994245
# dm:-0.021212910279558773, db:0.04821118967416297
# dm:-0.021161486240431533, db:0.04809548229186274
# dm:-0.02111023348300156, db:0.04798003209564176
# dm:-0.02105914630841147, db:0.04786484079304998
# dm:-0.02100821961801443, db:0.04774990982952554
# dm:-0.020957448846848394, db:0.04763524041765521
# dm:-0.020906829904516012, db:0.047520833563175824
# dm:-0.020856359122620145, db:0.04740669008809354
# dm:-0.020806033208033092, db:0.047292810651236174
# dm:-0.020755849201332666, db:0.047179195766532914
# dm:-0.020705804439867727, db:0.047065845819256324
# dm:-0.020655896524918244, db:0.04695276108046542
# dm:-0.020606123292477463, db:0.04683994171985291
# dm:-0.020556482787306152, db:0.04672738781715531
# dm:-0.020506973239845145, db:0.046615099372304084
# dm:-0.020457593045682582, db:0.04650307631445264
# dm:-0.0204083407473307, db:0.04639131850999082
# dm:-0.020359215017980027, db:0.046279825769683924
# dm:-0.020310214647091186, db:0.04616859785500882
# dm:-0.020261338527561474, db:0.04605763448379285
# dm:-0.02021258564434003, db:0.04594693533521976
# dm:-0.020163955064277594, db:0.04583650005428878
# dm:-0.02011544592711519, db:0.045726328255774565
# dm:-0.02006705743748416, db:0.04561641952774279
# dm:-0.020018788857761944, db:0.04550677343468745
# dm:-0.019970639501759514, db:0.04539738952030377
# dm:-0.019922608729072994, db:0.04528826730996845
# dm:-0.019874695940091947, db:0.045179406312931825
# dm:-0.019826900571533912, db:0.04507080602427689
# dm:-0.01977922209249572, db:0.04496246592665261
# dm:-0.019731660000928443, db:0.04485438549181945
# dm:-0.019684213820513698, db:0.04474656418202046
# dm:-0.019636883097882286, db:0.0446390014511997
# dm:-0.019589667400128203, db:0.044531696746090844
# dm:-0.019542566312627997, db:0.04442464950717362
# dm:-0.0194955794370677, db:0.044317859169536046
# dm:-0.01944870638972255, db:0.04421132516362809
# dm:-0.019401946799892933, db:0.04410504691594467
# dm:-0.01935530030853923, db:0.043999023849622176
# dm:-0.019308766567060744, db:0.043893255384971276
# dm:-0.01926234523619952, db:0.04378774093995459
# dm:-0.019216035985087476, db:0.04368247993060281
# dm:-0.019169838490369646, db:0.04357747177139437
# dm:-0.019123752435457497, db:0.043472715875581436
# dm:-0.01907777750983778, db:0.04336821165548817
# dm:-0.019031913408470953, db:0.04326395852277246
# dm:-0.018986159831258988, db:0.04315995588865551
# dm:-0.018940516482552162, db:0.0430562031641335
# dm:-0.018894983070747585, db:0.04295269976015229
# dm:-0.01884955930788479, db:0.04284944508777884
# dm:-0.01880424490932538, db:0.04274643855833915
# dm:-0.018759039593457, db:0.04264367958354468
# dm:-0.01871394308140998, db:0.04254116757561199
# dm:-0.01866895509683471, db:0.042438901947356555
# dm:-0.018624075365692327, db:0.04233688211228248
# dm:-0.018579303616051607, db:0.042235107484664816
# dm:-0.018534639577938883, db:0.042133577479614104
# dm:-0.018490082983181406, db:0.0420322915131397
# dm:-0.018445633565275323, db:0.041931249002204574
# dm:-0.018401291059270797, db:0.041830449364771795
# dm:-0.01835705520166438, db:0.041729892019846705
# dm:-0.018312925730302815, db:0.0416295763875163
# dm:-0.018268902384307967, db:0.041529501888978373
# dm:-0.01822498490399852, db:0.041429667946571026
# dm:-0.018181173030821597, db:0.041330073983799544
# dm:-0.01813746650729516, db:0.04123071942535701
# dm:-0.018093865076963606, db:0.041131603697141195
# dm:-0.018050368484331614, db:0.04103272622627714
# dm:-0.018006976474847242, db:0.04093408644112406
# dm:-0.017963688794837264, db:0.04083568377129643
# dm:-0.017920505191507154, db:0.04073751764766283
# dm:-0.017877425412872107, db:0.04063958750237025
# dm:-0.01783444920776415, db:0.04054189276883842
# dm:-0.017791576325795273, db:0.04044443288177124
# dm:-0.017748806517325168, db:0.04034720727716771
# dm:-0.01770613953346034, db:0.0402502153923178
# dm:-0.017663575126027748, db:0.04015345666581075
# dm:-0.01762111304756549, db:0.04005693053753519
# dm:-0.017578753051294378, db:0.03996063644868715
# dm:-0.017536494891120302, db:0.03986457384176534
# dm:-0.0174943383216218, db:0.03976874216057406
# dm:-0.01745228309802756, db:0.03967314085022711
# dm:-0.01741032897622056, db:0.03957776935714359
# dm:-0.01736847571272578, db:0.0394826271290496
# dm:-0.017326723064701472, db:0.039387713614977095
# dm:-0.01728507078992806, db:0.03929302826526563
# dm:-0.01724351864681258, db:0.039198570531557245
# dm:-0.017202066394372828, db:0.039104339866798433
# dm:-0.01716071379223827, db:0.03901033572523686
# dm:-0.017119460600638476, db:0.03891655756242166
# dm:-0.01707830658040906, db:0.03882300483519874
# dm:-0.017037251492979816, db:0.038729677001710705
# dm:-0.016996295100369114, db:0.038636573521396045
# dm:-0.01695543716519173, db:0.03854369385498242
# dm:-0.01691467745063946, db:0.0384510374644907
# dm:-0.016874015720492075, db:0.038358603813226644
# dm:-0.016833451739107847, db:0.03826639236578207
# dm:-0.01679298527142133, db:0.03817440258803121
# dm:-0.016752616082944684, db:0.038082633947126965
# dm:-0.016712343939756735, db:0.0379910859115015
# dm:-0.016672168608503696, db:0.03789975795086257
# dm:-0.016632089856411476, db:0.037808649536185346
# dm:-0.016592107451261974, db:0.03771776013971746
# dm:-0.016552221161398723, db:0.037627089234974
# dm:-0.01651243075573546, db:0.037536636296729764
# dm:-0.016472736003734223, db:0.037446400801025195
# dm:-0.016433136675427857, db:0.037356382225153695
# dm:-0.0163936325413944, db:0.03726658004766762
# dm:-0.016354223372770406, db:0.03717699374837036
# dm:-0.0163149089412468, db:0.037087622808313604
# dm:-0.016275689019062806, db:0.03699846670979726
# dm:-0.01623656337901084, db:0.03690952493636305
# dm:-0.016197531794423476, db:0.03682079697279657
# dm:-0.016158594039189584, db:0.036732282305117415
# dm:-0.01611974988773568, db:0.03664398042058299
# dm:-0.016080999115037464, db:0.03655589080768055
# dm:-0.01604234149660888, db:0.03646801295612804
# dm:-0.016003776808501513, db:0.036380346356870596
# dm:-0.015965304827317173, db:0.03629289050207296
# dm:-0.015926925330183767, db:0.03620564488512438
# dm:-0.015888638094769664, db:0.03611860900062987
# dm:-0.015850442899284573, db:0.03603178234440755
# dm:-0.015812339522461194, db:0.035945164413490716
# dm:-0.015774327743569867, db:0.03585875470611969
# dm:-0.015736407342415326, db:0.03577255272174007
# dm:-0.01569857809932529, db:0.035686557961002244
# dm:-0.01566083979516038, db:0.03560076992575567
# dm:-0.01562319221130748, db:0.03551518811904748
# dm:-0.01558563512968103, db:0.03542981204511886
# dm:-0.015548168332714477, db:0.03534464120940406
# dm:-0.015510791603371949, db:0.035259675118524125
# dm:-0.015473504725130056, db:0.03517491328028906
# dm:-0.015436307481995648, db:0.035090355203688674
# dm:-0.01539919965849042, db:0.035006000398894635
# dm:-0.015362181039655216, db:0.034921848377255905
# dm:-0.015325251411042906, db:0.03483789865129753
# dm:-0.015288410558731425, db:0.034754150734712955
# dm:-0.015251658269305413, db:0.03467060414236789
# dm:-0.015214994329865839, db:0.03458725839029242
# dm:-0.015178418528022448, db:0.03450411299568149
# dm:-0.015141930651899838, db:0.03442116747688913
# dm:-0.01510553049013182, db:0.03433842135342724
# dm:-0.015069217831856403, db:0.03425587414596413
# dm:-0.01503299246672333, db:0.03417352537631846
# dm:-0.014996854184881503, db:0.03409137456746114
# dm:-0.014960802776989041, db:0.034009421243507955
# dm:-0.014924838034211813, db:0.03392766492971688
# dm:-0.01488895974820803, db:0.03384610515249076
# dm:-0.014853167711139943, db:0.03376474143936973
# dm:-0.014817461715675032, db:0.03368357331902801
# dm:-0.014781841554973566, db:0.03360260032127445
# dm:-0.01474630702269275, db:0.033521821977048116
# dm:-0.01471085791299013, db:0.03344123781841486
# dm:-0.014675494020515895, db:0.033360847378565595
# dm:-0.014640215140410362, db:0.03328065019181488
# dm:-0.01460502106830915, db:0.03320064579359583
# dm:-0.014569911600344376, db:0.03312083372045619
# dm:-0.014534886533130434, db:0.033041213510060764
# dm:-0.014499945663774067, db:0.03296178470118486
# dm:-0.014465088789868148, db:0.032882546833712535
# dm:-0.014430315709496561, db:0.03280349944863259
# dm:-0.014395626221223257, db:0.03272464208803945
# dm:-0.01436102012409668, db:0.03264597429512787
# dm:-0.014326497217652593, db:0.03256749561418918
# dm:-0.014292057301906524, db:0.03248920559061119
# dm:-0.014257700177354208, db:0.03241110377087475
# dm:-0.014223425644969959, db:0.03233318970255124
# dm:-0.014189233506206673, db:0.03225546293429963
# dm:-0.014155123563000119, db:0.032177923015861566
# dm:-0.014121095617757096, db:0.03210056949806346
# dm:-0.014087149473353358, db:0.032023401932813236
# dm:-0.014053284933153757, db:0.03194641987309084
# dm:-0.014019501800982326, db:0.03186962287295536
# dm:-0.013985799881143013, db:0.031793010487535245
# dm:-0.013952178978404728, db:0.03171658227303024
# dm:-0.01391863889800904, db:0.031640337786705455
# dm:-0.013885179445661736, db:0.03156427658689213
# dm:-0.013851800427543044, db:0.03148839823298062
# dm:-0.013818501650290896, db:0.03141270228542299
# dm:-0.013785282921013367, db:0.03133718830572644
# dm:-0.01375214404728083, db:0.03126185585645258
# dm:-0.013719084837124917, db:0.031186704501215225
# dm:-0.013686105099041779, db:0.031111733804675946
# dm:-0.013653204641985864, db:0.03103694333254377
# dm:-0.013620383275368, db:0.030962332651572666
# dm:-0.013587640809064272, db:0.030887901329555618
# dm:-0.01355497705340077, db:0.03081364893532686
# dm:-0.013522391819162927, db:0.030739575038756385
# dm:-0.013489884917592102, db:0.030665679210747438
# dm:-0.013457456160381446, db:0.030591961023235616
# dm:-0.013425105359676484, db:0.030518420049185625
# dm:-0.013392832328075569, db:0.03044505586258846
# dm:-0.013360636878623506, db:0.03037186803846037
# dm:-0.01332851882482311, db:0.03029885615283634
# dm:-0.013296477980620095, db:0.030226019782772468
# dm:-0.013264514160406193, db:0.030153358506341967
# dm:-0.013232627179019296, db:0.030080871902632346
# dm:-0.01320081685175071, db:0.030008559551740234
# dm:-0.013169082994324288, db:0.02993642103477508
# dm:-0.01313742542290915, db:0.029864455933853524
# dm:-0.013105843954125321, db:0.029792663832092593
# dm:-0.013074338405025216, db:0.029721044313615476
# dm:-0.013042908593098385, db:0.029649596963545
# dm:-0.013011554336284092, db:0.029578321367998168
# dm:-0.012980275452951032, db:0.029507217114089546
# dm:-0.012949071761905332, db:0.029436283789925945
# dm:-0.012917943082391284, db:0.029365520984603617
# dm:-0.012886889234085725, db:0.029294928288207345
# dm:-0.01285591003709922, db:0.029224505291806608
# dm:-0.012825005311975463, db:0.0291542515874544
# dm:-0.01279417487968996, db:0.02908416676818411
# dm:-0.012763418561646606, db:0.029014250428007905
# dm:-0.012732736179679034, db:0.02894450216191391
# dm:-0.012702127556053117, db:0.0288749215658625
# dm:-0.012671592513453806, db:0.028805508236788253
# dm:-0.012641130875002588, db:0.028736261772590733
# dm:-0.012610742464239433, db:0.028667181772138967
# dm:-0.012580427105131667, db:0.028598267835264903
# dm:-0.012550184622061995, db:0.028529519562765355
# dm:-0.012520014839848029, db:0.028460936556391925
# dm:-0.012489917583717276, db:0.02839251841885826
# dm:-0.012459892679326678, db:0.028324264753829098
# dm:-0.012429939952742034, db:0.028256175165925747
# dm:-0.012400059230456801, db:0.02818824926071676
# dm:-0.012370250339374333, db:0.028120486644721478
# dm:-0.012340513106821938, db:0.0280528869254019
# dm:-0.01231084736053667, db:0.027985449711165934
# dm:-0.012281252928666515, db:0.027918174611364144
# dm:-0.012251729639777645, db:0.027851061236283964
# dm:-0.012222277322851305, db:0.027784109197148688
# dm:-0.012192895807270194, db:0.027717318106120103
# dm:-0.012163584922836979, db:0.027650687576288302
# dm:-0.012134344499756661, db:0.027584217221676255
# dm:-0.012105174368645036, db:0.02751790665723345
# dm:-0.012076074360527636, db:0.02745175549883457
# dm:-0.0120470443068319, db:0.027385763363279025
# dm:-0.012018084039392788, db:0.027319929868286536
# dm:-0.011989193390447461, db:0.027254254632496533
# dm:-0.01196037219263853, db:0.027188737275464593
# dm:-0.01193162027900992, db:0.027123377417661278
# dm:-0.011902937483007747, db:0.027058174680468856
# dm:-0.011874323638479584, db:0.02699312868617968
# dm:-0.011845778579669286, db:0.02692823905799487
# dm:-0.011817302141220527, db:0.026863505420021618
# dm:-0.011788894158173413, db:0.026798927397270113
# dm:-0.011760554465967871, db:0.02673450461565189
# dm:-0.011732282900437152, db:0.02667023670197747
# dm:-0.011704079297809145, db:0.02660612328395532
# dm:-0.011675943494703578, db:0.02654216399018905
# dm:-0.011647875328141488, db:0.026478358450172358
# dm:-0.01161987463552198, db:0.026414706294294543
# dm:-0.01159194125464591, db:0.026351207153829215
# dm:-0.01156407502369916, db:0.026287860660938318
# dm:-0.011536275781257821, db:0.026224666448667534
# dm:-0.011508543366287741, db:0.026161624150944363
# dm:-0.011480877618138466, db:0.026098733402577068
# dm:-0.01145327837654797, db:0.026035993839251148
# dm:-0.011425745481640437, db:0.02597340509752799
# dm:-0.011398278773923446, db:0.025910966814842357
# dm:-0.011370878094283535, db:0.025848678629502686
# dm:-0.01134354328399804, db:0.025786540180683677
# dm:-0.011316274184717182, db:0.0257245511084306
# dm:-0.01128907063848228, db:0.025662711053650256
# dm:-0.011261932487703536, db:0.025601019658116304
# dm:-0.0112348595751753, db:0.025539476564462316
# dm:-0.011207851744071018, db:0.025478081416179982
# dm:-0.01118090883793954, db:0.025416833857618688
# dm:-0.01115403070070157, db:0.025355733533984605
# dm:-0.011127217176663429, db:0.02529478009133257
# dm:-0.011100468110493662, db:0.025233973176572867
# dm:-0.011073783347242738, db:0.025173312437461643
# dm:-0.01104716273233223, db:0.025112797522601905
# dm:-0.011020606111553938, db:0.02505242808144237
# dm:-0.010994113331063815, db:0.024992203764276688
# dm:-0.010967684237404463, db:0.024932124222232822
# dm:-0.010941318677469614, db:0.02487218910728428
# dm:-0.010915016498530772, db:0.024812398072237375
# dm:-0.010888777548224038, db:0.024752750770733762
# dm:-0.010862601674553366, db:0.024693246857247754
# dm:-0.010836488725885236, db:0.02463388598708486
# dm:-0.010810438550951021, db:0.024574667816379105
# dm:-0.01078445099885202, db:0.024515592002089193
# dm:-0.010758525919041695, db:0.024456658202001748
# dm:-0.010732663161344469, db:0.024397866074723495
# dm:-0.010706862575941518, db:0.02433921527968271
# dm:-0.010681124013373733, db:0.02428070547712687
# dm:-0.010655447324544967, db:0.0242223363281188
# dm:-0.010629832360711688, db:0.024164107494538456
# dm:-0.010604278973494807, db:0.0241060186390758
# dm:-0.010578787014863106, db:0.024048069425234665
# dm:-0.010553356337153375, db:0.023990259517324176
# dm:-0.01052798679304301, db:0.023932588580464504
# dm:-0.01050267823558008, db:0.023875056280576068
# dm:-0.010477430518147497, db:0.02381766228438842
# dm:-0.010452243494496175, db:0.023760406259426325
# dm:-0.01042711701872075, db:0.023703287874017466
# dm:-0.01040205094526551, db:0.023646306797286815
# dm:-0.010377045128932375, db:0.023589462699151593
# dm:-0.010352099424863887, db:0.023532755250326165
# dm:-0.010327213688557416, db:0.023476184122313743
# dm:-0.010302387775849464, db:0.02341974898741054
# dm:-0.010277621542935062, db:0.023363449518695546
# dm:-0.010252914846341128, db:0.023307285390039418
# dm:-0.010228267542952658, db:0.023251256276091592
# dm:-0.01020367948998683, db:0.023195361852288134
# dm:-0.010179150545013577, db:0.023139601794841536
# dm:-0.010154680565937674, db:0.02308397578074587
# dm:-0.01013026941101384, db:0.023028483487768238
# dm:-0.010105916938830894, db:0.022973124594453033
# dm:-0.010081623008317237, db:0.022917898780117664
# dm:-0.010057387478748106, db:0.022862805724847075
# dm:-0.0100332102097244, db:0.022807845109500402
# dm:-0.010009091061197257, db:0.022753016615699135
# dm:-0.009985029893447628, db:0.022698319925832745
# dm:-0.009961026567094262, db:0.022643754723053355
# dm:-0.009937080943087354, db:0.02258932069127617
# dm:-0.00991319288271697, db:0.022535017515174022
# dm:-0.00988936224760284, db:0.022480844880179575
# dm:-0.009865588899701905, db:0.022426802472479558
# dm:-0.009841872701294108, db:0.022372889979018613
# dm:-0.009818213515001931, db:0.02231910708748952
# dm:-0.009794611203765827, db:0.022265453486340604
# dm:-0.00977106563086938, db:0.022211928864763898
# dm:-0.009747576659912067, db:0.02215853291270342
# dm:-0.009724144154829398, db:0.022105265320845408
# dm:-0.009700767979878103, db:0.022052125780622173
# dm:-0.009677447999647093, db:0.02199911398420499
# dm:-0.009654184079050054, db:0.02194622962450617
# dm:-0.009630976083317755, db:0.02189347239517847
# dm:-0.009607823878016248, db:0.021840841990607242
# dm:-0.009584727329023341, db:0.021788338105916516
# dm:-0.00956168630255257, db:0.021735960436958614
# dm:-0.009538700665127742, db:0.02168370868032099
# dm:-0.009515770283594033, db:0.021631582533320128
# dm:-0.009492895025126142, db:0.021579581693996985
# dm:-0.009470074757207994, db:0.02152770586112185
# dm:-0.00944730934764726, db:0.021475954734187543
# dm:-0.009424598664568387, db:0.021424328013409284
# dm:-0.0094019425764101, db:0.021372825399724515
# dm:-0.009379340951934562, db:0.02132144659478641
# dm:-0.009356793660211988, db:0.021270191300968
# dm:-0.009334300570631596, db:0.02121905922135688
# dm:-0.009311861552892431, db:0.02116805005975545
# dm:-0.009289476477014169, db:0.021117163520675497
# dm:-0.009267145213319209, db:0.02106639930934273
# dm:-0.009244867632450138, db:0.021015757131688535
# dm:-0.009222643605356554, db:0.020965236694352463
# dm:-0.009200473003295812, db:0.020914837704680313
# dm:-0.009178355697841015, db:0.020864559870718814
# dm:-0.009156291560871832, db:0.020814402901217978
# dm:-0.009134280464573763, db:0.020764366505627997
# dm:-0.009112322281436361, db:0.02071445039409925
# dm:-0.009090416884264929, db:0.020664654277475325
# dm:-0.00906856414616645, db:0.020614977867296158
# dm:-0.009046763940548114, db:0.020565420875797415
# dm:-0.009025016141129308, db:0.020515983015903256
# dm:-0.009003320621925473, db:0.020466664001230907
# dm:-0.008981677257262769, db:0.020417463546082832
# dm:-0.008960085921760156, db:0.020368381365452194
# dm:-0.008938546490348346, db:0.0203194171750131
# dm:-0.008917058838248188, db:0.0202705706911274
# dm:-0.00889562284099125, db:0.020221841630834476
# dm:-0.008874238374398935, db:0.02017322971185731
# dm:-0.008852905314598184, db:0.02012473465259538
# dm:-0.008831623538004152, db:0.02007635617212807
# dm:-0.008810392921342261, db:0.020028093990205626
# dm:-0.0087892133416263, db:0.019979947827254797
# dm:-0.008768084676165522, db:0.01993191740437439
# dm:-0.008747006802564941, db:0.019884002443333472
# dm:-0.008725979598726969, db:0.019836202666568898
# dm:-0.008705002942840748, db:0.019788517797187044
# dm:-0.008684076713396955, db:0.019740947558956723
# dm:-0.00866320078917271, db:0.01969349167631303
# dm:-0.008642375049234078, db:0.019646149874354236
# dm:-0.00862159937294719, db:0.019598921878836308
# dm:-0.008600873639959575, db:0.01955180741617705
# dm:-0.008580197730210088, db:0.01950480621345211
# dm:-0.008559571523929202, db:0.01945791799839114
# dm:-0.008538994901632494, db:0.01941114249938014
# dm:-0.008518467744121386, db:0.019364479445458084
# dm:-0.00849798993248744, db:0.01931792856631409
# dm:-0.00847756134811058, db:0.01927148959228623
# dm:-0.008457181872644437, db:0.019225162254365248
# dm:-0.008436851388038846, db:0.019178946284183596
# dm:-0.008416569776522387, db:0.01913284141402164
# dm:-0.008396336920606965, db:0.019086847376802513
# dm:-0.00837615270308974, db:0.019040963906090447
# dm:-0.008356017007044986, db:0.018995190736092127
# dm:-0.008335929715832968, db:0.01894952760165136
# dm:-0.008315890713087803, db:0.01890397423825174
# dm:-0.00829589988273094, db:0.018858530382009686
# dm:-0.008275957108954568, db:0.01881319576967947
# dm:-0.008256062276239835, db:0.018767970138643914
# dm:-0.008236215269338782, db:0.01872285322691969
# dm:-0.00821641597327612, db:0.01867784477315526
# dm:-0.008196664273362703, db:0.01863294451662334
# dm:-0.008176960055180722, db:0.018588152197225316
# dm:-0.00815730320458637, db:0.018543467555488004
# dm:-0.008137693607712215, db:0.01849889033256128
# dm:-0.00811813115096142, db:0.01845442027021852
# dm:-0.008098615721015001, db:0.01841005711085201
# dm:-0.008079147204821464, db:0.018365800597475612
# dm:-0.0080597254896048, db:0.01832165047371855
# dm:-0.008040350462855153, db:0.018277606483829107
# dm:-0.008021022012343632, db:0.018233668372666045
# dm:-0.008001740026097881, db:0.01818983588570644
# dm:-0.007982504392421319, db:0.018146108769037106
# dm:-0.007963314999891224, db:0.01810248676935296
# dm:-0.007944171737343925, db:0.01805896963396088
# dm:-0.007925074493881763, db:0.018015557110775994
# dm:-0.007906023158885962, db:0.017972248948315023
# dm:-0.007887017621987624, db:0.01792904489570457
# dm:-0.007868057773099697, db:0.017885944702668983
# dm:-0.007849143502382638, db:0.017842948119540125
# dm:-0.007830274700275197, db:0.01780005489724464
# dm:-0.00781145125747192, db:0.017757264787311062
# dm:-0.007792673064932772, db:0.017714577541864042
# dm:-0.007773940013880912, db:0.017671992913623903
# dm:-0.00775525199579589, db:0.017629510655906934
# dm:-0.007736608902425482, db:0.01758713052262036
# dm:-0.007718010625770599, db:0.017544852268265
# dm:-0.007699457058095345, db:0.017502675647930843
# dm:-0.007680948091924359, db:0.017460600417295837
# dm:-0.007662483620035705, db:0.017418626332627102
# dm:-0.007644063535471535, db:0.01737675315077558
# dm:-0.007625687731526979, db:0.017334980629178265
# dm:-0.007607356101751931, db:0.017293308525855533
# dm:-0.007589068539957407, db:0.01725173659940804
# dm:-0.007570824940205334, db:0.017210264609017756
# dm:-0.007552625196813286, db:0.01716889231444559
# dm:-0.0075344692043550765, db:0.017127619476029327
# dm:-0.0075163568576558735, db:0.01708644585468318
# dm:-0.00749828805179605, db:0.01704537121189542
# dm:-0.0074802626821028895, db:0.01700439530972986
# dm:-0.007462280644163025, db:0.016963517910819327
# dm:-0.007444341833807044, db:0.016922738778369546
# dm:-0.0074264461471186625, db:0.01688205767615495
# dm:-0.007408593480432509, db:0.01684147436851709
# dm:-0.007390783730334416, db:0.016800988620363423
# dm:-0.00737301679364899, db:0.016760600197170294
# dm:-0.007355292567462109, db:0.01672030886497285
# dm:-0.0073376109490979795, db:0.01668011439037172
# dm:-0.0073199718361314225, db:0.016640016540527824
# dm:-0.0073023751263806185, db:0.016600015083162518
# dm:-0.007284820717910959, db:0.016560109786554644
# dm:-0.007267308509034601, db:0.016520300419540074
# dm:-0.007249838398306174, db:0.016480586751510685
# dm:-0.0072324102845248515, db:0.016440968552412578
# dm:-0.0072150240667306536, db:0.016401445592745922
# dm:-0.00719767964421288, db:0.01636201764356008
# dm:-0.007180376916496792, db:0.016322684476456868
# dm:-0.007163115783348051, db:0.016283445863587875
# dm:-0.007145896144779821, db:0.01624430157764974
# dm:-0.007128717901038269, db:0.016205251391888588
# dm:-0.007111580952618693, db:0.016166295080091597
# dm:-0.0070944852002448044, db:0.016127432416594385
# dm:-0.007077430544885743, db:0.016088663176272295
# dm:-0.007060416887747796, db:0.01604998713454216
# dm:-0.007043444130274246, db:0.01601140406736068
# dm:-0.007026512174143296, db:0.01597291375122441
# dm:-0.007009620921271627, db:0.015934515963165936
# dm:-0.006992770273812768, db:0.015896210480753403
# dm:-0.006975960134154875, db:0.015857997082090382
# dm:-0.006959190404916289, db:0.015819875545814988
# dm:-0.006942460988956345, db:0.015781845651095562
# dm:-0.006925771789365745, db:0.015743907177631446
# dm:-0.0069091227094630146, db:0.015706059905653547
# dm:-0.006892513652807371, db:0.015668303615918568
# dm:-0.006875944523182001, db:0.015630638089712434
# dm:-0.006859415224607386, db:0.015593063108845229
# dm:-0.006842925661331378, db:0.015555578455652547
# dm:-0.006826475737834384, db:0.015518183912992384
# dm:-0.006810065358822115, db:0.015480879264246164
# dm:-0.006793694429233277, db:0.015443664293314896
# dm:-0.006777362854237504, db:0.015406538784617988
# dm:-0.0067610705392254404, db:0.015369502523095472
# dm:-0.006744817389821763, db:0.015332555294202669
# dm:-0.006728603311871417, db:0.015295696883912116
# dm:-0.006712428211454272, db:0.015258927078708387
# dm:-0.006696291994864101, db:0.015222245665593418
# dm:-0.006680194568635518, db:0.015185652432075553
# dm:-0.006664135839512753, db:0.01514914716617947
# dm:-0.006648115714470807, db:0.01511272965643684
# dm:-0.006632134100711025, db:0.015076399691886936
# dm:-0.006616190905654573, db:0.015040157062077212
# dm:-0.006600286036943477, db:0.015004001557061681
# dm:-0.006584419402445066, db:0.014967932967397957
# dm:-0.006568590910245605, db:0.014931951084147983
# dm:-0.006552800468656657, db:0.014896055698874347
# dm:-0.006537047986201472, db:0.014860246603643823
# dm:-0.006521333371635999, db:0.014824523591018785
# dm:-0.006505656533922247, db:0.01478888645406462
# dm:-0.006490017382252707, db:0.01475333498634009
# dm:-0.006474415826029626, db:0.014717868981903266
# dm:-0.006458851774877002, db:0.014682488235306046
# dm:-0.0064433251386336226, db:0.014647192541595189
# dm:-0.006427835827357212, db:0.014611981696309062
# dm:-0.00641238375132458, db:0.014576855495476604
# dm:-0.006396968821019625, db:0.014541813735620135
# dm:-0.006381590947148297, db:0.014506856213748698
# dm:-0.006366250040634143, db:0.014471982727358649
# dm:-0.006350946012601, db:0.01443719307443736
# dm:-0.006335678774403478, db:0.014402487053452262
# dm:-0.006320448237597216, db:0.014367864463359284
# dm:-0.0063052543139556026, db:0.014333325103596195
# dm:-0.006290096915464153, db:0.0142988687740823
# dm:-0.006274975954316956, db:0.014264495275219335
# dm:-0.006259891342922448, db:0.014230204407887765
# dm:-0.006244842993898972, db:0.014195995973446784
# dm:-0.006229830820074629, db:0.014161869773733274
# dm:-0.006214854734480468, db:0.0141278256110627
# dm:-0.006199914650371211, db:0.01409386328822082
# dm:-0.006185010481200533, db:0.014059982608470634
# dm:-0.006170142140626389, db:0.014026183375549431
# dm:-0.006155309542524042, db:0.013992465393663167
# dm:-0.006140512600968151, db:0.013958828467491042
# dm:-0.006125751230242689, db:0.013925272402180333
# dm:-0.006111025344840944, db:0.01389179700334638
# dm:-0.006096334859457227, db:0.013858402077072896
# dm:-0.006081679688989983, db:0.013825087429910028
# dm:-0.006067059748548005, db:0.013791852868871116
# dm:-0.0060524749534374145, db:0.013758698201435937
# dm:-0.00603792521917453, db:0.01372562323554464
# dm:-0.006023410461472108, db:0.013692627779601155
# dm:-0.006008930596250886, db:0.013659711642468448
# dm:-0.005994485539633961, db:0.013626874633468825
# dm:-0.005980075207937603, db:0.0135941165623857
# dm:-0.005965699517693915, db:0.013561437239454872
# dm:-0.005951358385620775, db:0.013528836475373543
# dm:-0.005937051728643894, db:0.013496314081291
# dm:-0.005922779463889712, db:0.013463869868810688
# dm:-0.005908541508679033, db:0.013431503649990054
# dm:-0.0058943377805350155, db:0.013399215237337595
# dm:-0.005880168197179328, db:0.013367004443811965
# dm:-0.005866032676526818, db:0.013334871082823458
# dm:-0.005851931136697648, db:0.01330281496822779
# dm:-0.005837863496003829, db:0.013270835914330387
# dm:-0.005823829672951289, db:0.013238933735883435
# dm:-0.005809829586242839, db:0.01320710824808439
# dm:-0.005795863154784678, db:0.013175359266572132
# dm:-0.005781930297665383, db:0.013143686607432887
# dm:-0.005768030934182396, db:0.013112090087190015
# dm:-0.005754164983814794, db:0.01308056952281289
# dm:-0.005740332366236907, db:0.013049124731709494
# dm:-0.005726533001324086, db:0.013017755531724498
# dm:-0.005712766809134498, db:0.012986461741143557
# dm:-0.005699033709927044, db:0.012955243178686349
# dm:-0.005685333624147729, db:0.012924099663509825
# dm:-0.005671666472434407, db:0.012893031015205558
# dm:-0.005658032175616334, db:0.012862037053798403
# dm:-0.005644430654709431, db:0.01283111759974768
# dm:-0.0056308618309264995, db:0.01280027247394111
# dm:-0.005617325625664045, db:0.012769501497699398
# dm:-0.0056038219605104205, db:0.012738804492771944
# dm:-0.005590350757240495, db:0.012708181281336845
# dm:-0.0055769119378178775, db:0.012677631685999852
# dm:-0.005563505424393729, db:0.012647155529792897
# dm:-0.005550131139308541, db:0.012616752636172901
# dm:-0.00553678900508873, db:0.012586422829021041
# dm:-0.005523478944440718, db:0.012556165932644229
# dm:-0.00551020088026514, db:0.012525981771769185
# dm:-0.005496954735646042, db:0.01249587017154378
# dm:-0.005483740433847324, db:0.012465830957538799
# dm:-0.005470557898322366, db:0.01243586395574218
# dm:-0.005457407052708548, db:0.012405968992560338
# dm:-0.005444287820823253, db:0.01237614589481802
# dm:-0.0054312001266726044, db:0.012346394489754609
# dm:-0.005418143894438435, db:0.012316714605027071
# dm:-0.005405119048492353, db:0.012287106068703904
# dm:-0.005392125513381381, db:0.012257568709269417
# dm:-0.0053791632138369865, db:0.012228102355619145
# dm:-0.005366232074770197, db:0.012198706837060294
# dm:-0.005353332021273527, db:0.012169381983310116
# dm:-0.005340462978622451, db:0.012140127624494124
# dm:-0.005327624872262829, db:0.012110943591149503
# dm:-0.005314817627830296, db:0.012081829714217266
# dm:-0.005302041171135752, db:0.0120527858250458
# dm:-0.005289295428166548, db:0.01202381175538969
# dm:-0.0052765803250869325, db:0.011994907337408378
# dm:-0.005263895788240269, db:0.011966072403664244
# dm:-0.005251241744150666, db:0.011937306787120683
# dm:-0.0052386181195157215, db:0.011908610321144023
# dm:-0.005226024841207266, db:0.011879982839501608
# dm:-0.005213461836273432, db:0.011851424176360315
# dm:-0.00520092903194147, db:0.011822934166284327
# dm:-0.005188426355614191, db:0.01179451264423544
# dm:-0.0051759537348584255, db:0.011766159445575722
# dm:-0.0051635110974264835, db:0.011737874406059074
# dm:-0.005151098371242835, db:0.011709657361834786
# dm:-0.005138715484400258, db:0.011681508149447831
# dm:-0.005126362365166799, db:0.011653426605835163
# dm:-0.005114038941986069, db:0.011625412568324537
# dm:-0.005101745143467025, db:0.011597465874637614
# dm:-0.005089480898393894, db:0.011569586362884188
# dm:-0.005077246135727205, db:0.011541773871561745
# dm:-0.005065040784587212, db:0.011514028239559899
# dm:-0.005052864774273876, db:0.011486349306152555
# dm:-0.00504071803425532, db:0.011458736911000262
# dm:-0.005028600494163685, db:0.011431190894150825
# dm:-0.0050165120838086, db:0.011403711096034108
# dm:-0.005004452733161931, db:0.011376297357465443
# dm:-0.00499242237236371, db:0.01134894951964327
# dm:-0.004980420931729235, db:0.011321667424144977
# dm:-0.004968448341732934, db:0.0112944509129315
# dm:-0.004956504533022432, db:0.011267299828341848
# dm:-0.004944589436407002, db:0.01124021401309605
# dm:-0.004932702982867039, db:0.011213193310290137
# dm:-0.004920845103542367, db:0.011186237563399832
# dm:-0.00490901572974837, db:0.011159346616273305
# dm:-0.004897214792953204, db:0.011132520313138864
# dm:-0.004885442224803841, db:0.011105758498594001
# dm:-0.00487369795709854, db:0.011079061017614578
# dm:-0.004861981921809051, db:0.011052427715545635
# dm:-0.004850294051061965, db:0.011025858438107031
# dm:-0.004838634277152772, db:0.01099935303138766
# dm:-0.004827002532540388, db:0.010972911341846192
# dm:-0.004815398749841529, db:0.010946533216311671
# dm:-0.004803822861843739, db:0.010920218501978477
# dm:-0.0047922748014840675, db:0.01089396704641284
# dm:-0.0047807545018681745, db:0.010867778697544109
# dm:-0.0047692618962623294, db:0.010841653303668004
# dm:-0.004757796918092083, db:0.010815590713444696
# dm:-0.004746359500942117, db:0.01078959077589925
# dm:-0.004734949578556838, db:0.010763653340418955
# dm:-0.004723567084840526, db:0.010737778256753186
# dm:-0.00471221195386103, db:0.010711965375010882
# dm:-0.004700884119834084, db:0.01068621454566528
# dm:-0.004689583517143732, db:0.010660525619545039
# dm:-0.004678310080323674, db:0.010634898447840452
# dm:-0.004667063744072515, db:0.010609332882097089
# dm:-0.004655844443243851, db:0.010583828774217707
# dm:-0.004644652112843446, db:0.010558385976463006
# dm:-0.004633486688036055, db:0.010533004341447771
# dm:-0.004622348104143044, db:0.010507683722140577
# dm:-0.004611236296642543, db:0.010482423971863348
# dm:-0.004600151201162639, db:0.010457224944292243
# dm:-0.004589092753493654, db:0.01043208649345247
# dm:-0.0045780608895705415, db:0.010407008473723778
# dm:-0.004567055545494488, db:0.010381990739831554
# dm:-0.004556076657507309, db:0.010357033146854988
# dm:-0.0045451241620152825, db:0.010332135550217725
# dm:-0.004534197995569459, db:0.010307297805693949
# dm:-0.0045232980948777994, db:0.010282519769402754
# dm:-0.004512424396795556, db:0.010257801297810953
# dm:-0.0045015768383418475, db:0.01023314224772598
# dm:-0.004490755356675535, db:0.01020854247630402
# dm:-0.0044799598891041015, db:0.01018400184104499
# dm:-0.004469190373095788, db:0.010159520199788385
# dm:-0.0044584467462665716, db:0.010135097410715943
# dm:-0.004447728946377497, db:0.010110733332351943
# dm:-0.004437036911341785, db:0.010086427823560543
# dm:-0.004426370579225569, db:0.010062180743542962
# dm:-0.004415729888240053, db:0.010037991951840889
# dm:-0.004405114776745951, db:0.010013861308333222
# dm:-0.004394525183249934, db:0.009989788673236372
# dm:-0.0043839610464078875, db:0.009965773907102182
# dm:-0.004373422305028166, db:0.009941816870816151
# dm:-0.004362908898056942, db:0.009917917425601441
# dm:-0.004352420764595817, db:0.00989407543301161
# dm:-0.0043419578438883555, db:0.009870290754934914
# dm:-0.004331520075320375, db:0.009846563253592528
# dm:-0.004321107398434461, db:0.009822892791533514
# dm:-0.004310719752909531, db:0.009799279231639849
# dm:-0.004300357078569572, db:0.009775722437123619
# dm:-0.004290019315387342, db:0.009752222271524206
# dm:-0.00427970640347904, db:0.009728778598709168
# dm:-0.004269418283102529, db:0.009705391282874249
# dm:-0.004259154894660888, db:0.009682060188541008
# dm:-0.004248916178702267, db:0.009658785180556073
# dm:-0.004238702075911445, db:0.009635566124093367
# dm:-0.004228512527123899, db:0.009612402884647745
# dm:-0.004218347473310698, db:0.009589295328040018
# dm:-0.004208206855590942, db:0.009566243320411338
# dm:-0.00419809061522051, db:0.009543246728226151
# dm:-0.004187998693593838, db:0.009520305418271017
# dm:-0.004177931032257239, db:0.009497419257648982
# dm:-0.004167887572883444, db:0.00947458811378728
# dm:-0.004157868257297951, db:0.009451811854427264
# dm:-0.004147873027462149, db:0.009429090347630027
# dm:-0.004137901825469322, db:0.009406423461776559
# dm:-0.004127954593561967, db:0.009383811065560188
# dm:-0.004118031274119804, db:0.009361253027991179
# dm:-0.004108131809654155, db:0.009338749218396428
# dm:-0.004098256142823775, db:0.009316299506413994
# dm:-0.004088404216416356, db:0.009293903761998863
# dm:-0.004078575973364658, db:0.009271561855415406
# dm:-0.004068771356735852, db:0.00924927365724093
# dm:-0.00405899030972782, db:0.009227039038366414
# dm:-0.004049232775687361, db:0.00920485786998837
# dm:-0.004039498698090652, db:0.009182730023615655
# dm:-0.004029788020546062, db:0.00916065537106725
# dm:-0.004020100686804214, db:0.009138633784467812
# dm:-0.0040104366407479235, db:0.009116665136250646
# dm:-0.004000795826393677, db:0.009094749299155916
# dm:-0.0039911781878968116, db:0.009072886146228438
# dm:-0.0039815836695423395, db:0.009051075550819743
# dm:-0.003972012215750867, db:0.009029317386585115
# dm:-0.003962463771076526, db:0.009007611527483897
# dm:-0.003952938280208447, db:0.00898595784777741
# dm:-0.003943435687966771, db:0.00896435622203029
# dm:-0.003933955939303975, db:0.008942806525108555
# dm:-0.003924498979307541, db:0.00892130863217814
# dm:-0.003915064753193143, db:0.008899862418706661
# dm:-0.0039056532063098297, db:0.008878467760460307
# dm:-0.003896264284139435, db:0.00885712453350355
# dm:-0.0038868979322925767, db:0.00883583261419929
# dm:-0.0038775540965117665, db:0.008814591879207523
# dm:-0.003868232722673633, db:0.008793402205483414
# dm:-0.0038589337567769277, db:0.008772263470280706
# dm:-0.0038496571449540733, db:0.008751175551146684
# dm:-0.0038404028334717566, db:0.008730138325921583
# dm:-0.0038311707687171586, db:0.008709151672742294
# dm:-0.003821960897214242, db:0.008688215470035843
# dm:-0.003812773165608352, db:0.008667329596523832
# dm:-0.0038036075206792455, db:0.008646493931217709
# dm:-0.003794463909331321, db:0.008625708353420542
# dm:-0.003785342278596578, db:0.008604972742725536
# dm:-0.003776242575637874, db:0.00858428697901455
# dm:-0.0037671647477373798, db:0.00856365094246018
# dm:-0.0037581087423127118, db:0.008543064513520863
# dm:-0.003749074506904056, db:0.008522527572943101
# dm:-0.0037400619891784594, db:0.008502040001760136
# dm:-0.00373107113692465, db:0.008481601681292378
# dm:-0.003722101898065914, db:0.00846121249314254
# dm:-0.003713154220637893, db:0.008440872319202725
# dm:-0.0037042280528127116, db:0.008420581041644226
# dm:-0.003695323342883139, db:0.008400338542923583
# dm:-0.0036864400392664365, db:0.008380144705779635
# dm:-0.00367757809049903, db:0.00835999941323499
# dm:-0.003668737445245392, db:0.008339902548591294
# dm:-0.0036599180523027757, db:0.008319853995428042
# dm:-0.0036511198605698363, db:0.008299853637612356
# dm:-0.003642342819087633, db:0.00827990135928284
# dm:-0.003633586877011208, db:0.00825999704486054
# dm:-0.0036248519836190596, db:0.00824014057904332
# dm:-0.0036161380883101835, db:0.008220331846807039
# dm:-0.0036074451406073274, db:0.00820057073340319
# dm:-0.0035987730901526995, db:0.008180857124359637
# dm:-0.0035901218867116684, db:0.00816119090547899
# dm:-0.003581491480171284, db:0.008141571962837713
# dm:-0.003572881820536722, db:0.008122000182787303
# dm:-0.0035642928579317315, db:0.008102475451952973
# dm:-0.0035557245426042585, db:0.008082997657230676
# dm:-0.0035471768249163795, db:0.008063566685790372
# dm:-0.0035386496553564406, db:0.00804418242507099
# dm:-0.003530142984524254, db:0.00802484476278457
# dm:-0.0035216567631484175, db:0.008005553586909315
# dm:-0.003513190942063519, db:0.007986308785697283
# dm:-0.0035047454722308595, db:0.007967110247666387
# dm:-0.003496320304729424, db:0.007947957861602331
# dm:-0.003487915390752179, db:0.007928851516559346
# dm:-0.003479530681611405, db:0.007909791101858113
# dm:-0.0034711661287355846, db:0.007890776507085324
# dm:-0.003462821683672216, db:0.007871807622092348
# dm:-0.0034544972980798208, db:0.007852884336997304
# dm:-0.0034461929237371196, db:0.00783400654218121
# dm:-0.0034379085125430344, db:0.007815174128286806
# dm:-0.0034296440165043998, db:0.0077963869862225366
# dm:-0.0034213993877475106, db:0.00777764500715783
# dm:-0.003413174578510869, db:0.0077589480825244195
# dm:-0.003404969541152288, db:0.007740296104013685
# dm:-0.003396784228139123, db:0.007721688963579313
# dm:-0.0033886185920562655, db:0.0077031265534331555
# dm:-0.003380472585600665, db:0.007684608766047152
# dm:-0.003372346161587103, db:0.007666135494149924
# dm:-0.003364239272938274, db:0.007647706630730481
# dm:-0.0033561518726930766, db:0.007629322069033476
# dm:-0.003348083914001876, db:0.007610981702560989
# dm:-0.0033400353501313873, db:0.007592685425069708
# dm:-0.0033320061344556486, db:0.007574433130573451
# dm:-0.003323996220463865, db:0.007556224713339757
# dm:-0.00331600556175123, db:0.007538060067892556
# dm:-0.0033080341120359513, db:0.007519939089005204
# dm:-0.0033000818251405955, db:0.007501861671706115
# dm:-0.003292148654995053, db:0.007483827711277868
# dm:-0.0032842345556463037, db:0.007465837103252178
# dm:-0.0032763394812493907, db:0.007447889743413001
# dm:-0.00326846338606875, db:0.007429985527794909
# dm:-0.0032606062244805814, db:0.007412124352681904
# dm:-0.003252767950969293, db:0.00739430611460771
# dm:-0.003244948520130464, db:0.007376530710354008
# dm:-0.003237147886664922, db:0.007358798036952496
# dm:-0.0032293660053883677, db:0.007341107991679714
# dm:-0.0032216028312198235, db:0.007323460472061486
# dm:-0.0032138583191885966, db:0.007305855375868919
# dm:-0.003206132424433387, db:0.007288292601118703
# dm:-0.003198425102196515, db:0.007270772046074144
# dm:-0.0031907363078359135, db:0.007253293609239986
# dm:-0.003183065996807214, db:0.007235857189368773
# dm:-0.0031754141246803274, db:0.007218462685453453
# dm:-0.003167780647127749, db:0.007201109996731958
# dm:-0.00316016551993048, db:0.007183799022682772
# dm:-0.0031525686989786195, db:0.007166529663026111
# dm:-0.003144990140259966, db:0.007149301817725254
# dm:-0.003137429799876597, db:0.007132115386981811
# dm:-0.003129887634034804, db:0.007114970271236901
# dm:-0.0031223635990407965, db:0.007097866371173674
# dm:-0.0031148576513113646, db:0.0070808035877116815
# dm:-0.003107369747361292, db:0.007063781822010876
# dm:-0.003099899843822751, db:0.007046800975464654
# dm:-0.0030924478974165837, db:0.007029860949708736
# dm:-0.0030850138649802794, db:0.007012961646610952
# dm:-0.0030775977034454742, db:0.00699610296827835
# dm:-0.003070199369856752, db:0.006979284817049939
# dm:-0.0030628188213521015, db:0.006962507095503204
# dm:-0.003055456015179351, db:0.00694576970644715
# dm:-0.0030481109086875806, db:0.00692907255292526
# dm:-0.0030407834593287513, db:0.006912415538213571
# dm:-0.003033473624654448, db:0.006895798565821861
# dm:-0.003026181362320616, db:0.006879221539491276
# dm:-0.003018906630083862, db:0.006862684363194186
# dm:-0.0030116493858029316, db:0.006846186941133888
# dm:-0.003004409587439897, db:0.006829729177743419
# dm:-0.0029971871930539367, db:0.0068133109776867444
# dm:-0.0029899821608097748, db:0.0067969322458550545
# dm:-0.0029827944489683547, db:0.0067805928873704655
# dm:-0.00297562401589202, db:0.0067642928075820246
# dm:-0.0029684708200443666, db:0.0067480319120664465
# dm:-0.0029613348199892067, db:0.006731810106627082
# dm:-0.0029542159743896805, db:0.006715627297293617
# dm:-0.0029471142420079604, db:0.0066994833903223725
# dm:-0.002940029581699181, db:0.006683378292196451
# dm:-0.0029329619524280184, db:0.006667311909620702
# dm:-0.0029259113132530006, db:0.006651284149525279
# dm:-0.002918877623330947, db:0.006635294919064745
# dm:-0.0029118608419146, db:0.006619344125617191
# dm:-0.0029048609283618037, db:0.006603431676780976
# dm:-0.002897877842119219, db:0.006587557480379758
# dm:-0.002890911542737721, db:0.006571721444456576
# dm:-0.002883961989859962, db:0.006555923477277107
# dm:-0.002877029143231476, db:0.0065401634873256675
# dm:-0.002870112962689723, db:0.006524441383308469
# dm:-0.002863213408168826, db:0.006508757074150662
# dm:-0.002856330439708306, db:0.006493110468993516
# dm:-0.0028494640174288044, db:0.00647750147720183
# dm:-0.0028426141015562103, db:0.006461930008355191
# dm:-0.0028357806524111533, db:0.006446395972250496
# dm:-0.002828963630409742, db:0.006430899278901799
# dm:-0.002822162996061787, db:0.006415439838540019
# dm:-0.00281537870997021, db:0.006400017561611755
# dm:-0.002808610732839926, db:0.006384632358777509
# dm:-0.002801859025458449, db:0.0063692841409156795
# dm:-0.0027951235487195802, db:0.006353972819115464
# dm:-0.0027884042636037165, db:0.006338698304682033
# dm:-0.0027817011311889552, db:0.006323460509132239
# dm:-0.00277501411264236, db:0.006308259344197431
# dm:-0.002768343169230173, db:0.006293094721819159
# dm:-0.0027616882623095287, db:0.006277966554151544
# dm:-0.0027550493533262293, db:0.006262874753561132
# dm:-0.002748426403824518, db:0.006247819232623038
# dm:-0.0027418193754396762, db:0.006232799904123324
# dm:-0.0027352282298977273, db:0.006217816681058104
# dm:-0.0027286529290157326, db:0.006202869476632955
# dm:-0.0027220934347077135, db:0.00618795820426025
# dm:-0.002715549708974289, db:0.006173082777562714
# dm:-0.002709021713906227, db:0.006158243110370165
# dm:-0.0027025094116878514, db:0.006143439116719662
# dm:-0.002696012764600593, db:0.00612867071085225
# dm:-0.002689531735007448, db:0.006113937807218435
# dm:-0.0026830662853603764, db:0.00609924032047493
# dm:-0.0026766163782114085, db:0.006084578165480359
# dm:-0.0026701819761988745, db:0.006069951257298663
# dm:-0.0026637630420465186, db:0.006055359511200287
# dm:-0.002657359538568234, db:0.006040802842658917
# dm:-0.0026509714286759114, db:0.006026281167348083
# dm:-0.0026445986753588593, db:0.006011794401148703
# dm:-0.0026382412417037906, db:0.0059973424601403496
# dm:-0.0026318990908832753, db:0.00598292526060599
# dm:-0.002625572186156333, db:0.005968542719029912
# dm:-0.00261926049087761, db:0.0059541947520950576
# dm:-0.0026129639684799124, db:0.00593988127668806
# Optimized m: 1.4891565847482928
# Optimized b: 0.3579829649416946
